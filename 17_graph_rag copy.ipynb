# %% [markdown]
# # Graph RAG: Graph-Enhanced Retrieval-Augmented Generation
#
# In this notebook, I implement Graph RAG - a technique that enhances traditional RAG systems by organizing knowledge as a connected graph rather than a flat collection of documents. This allows the system to navigate related concepts and retrieve more contextually relevant information than standard vector similarity approaches.
#
# Key Benefits of Graph RAG
#
# - Preserves relationships between pieces of information
# - Enables traversal through connected concepts to find relevant context
# - Improves handling of complex, multi-part queries
# - Provides better explainability through visualized knowledge paths

# %% [markdown]
# ## Setting Up the Environment
# We begin by importing necessary libraries.

# %%
import os
import numpy as np
import json
import fitz  # PyMuPDF
from openai import OpenAI
from typing import List, Dict, Tuple, Any
import networkx as nx
import matplotlib.pyplot as plt
import heapq
from collections import defaultdict
import re
from PIL import Image
import io

# %% [markdown]
# ## Setting Up the OpenAI API Client
# We initialize the OpenAI client to generate embeddings and responses.

# %%
# Initialize the OpenAI client with the base URL and API key
client = OpenAI(
    base_url="https://api.studio.nebius.com/v1/",
    api_key=os.getenv("NEBIUS_API_KEY")  # Retrieve the API key from environment variables
)

# %% [markdown]
# ## Document Processing Functions

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extract text content from a PDF file.
    
    Args:
        pdf_path (str): Path to the PDF file
        
    Returns:
        str: Extracted text content
    """
    print(f"Extracting text from {pdf_path}...")  # Print the path of the PDF being processed
    pdf_document = fitz.open(pdf_path)  # Open the PDF file using PyMuPDF
    text = ""  # Initialize an empty string to store the extracted text
    
    # Iterate through each page in the PDF
    for page_num in range(pdf_document.page_count):
        page = pdf_document[page_num]  # Get the page object
        text += page.get_text()  # Extract text from the page and append to the text string
    
    return text  # Return the extracted text content

# %%
def chunk_text(text, chunk_size=1000, overlap=200):
    """
    Split text into overlapping chunks.
    
    Args:
        text (str): Input text to chunk
        chunk_size (int): Size of each chunk in characters
        overlap (int): Overlap between chunks in characters
        
    Returns:
        List[Dict]: List of chunks with metadata
    """
    chunks = []  # Initialize an empty list to store the chunks
    
    # Iterate over the text with a step size of (chunk_size - overlap)
    for i in range(0, len(text), chunk_size - overlap):
        # Extract a chunk of text from the current position
        chunk_text = text[i:i + chunk_size]
        
        # Ensure we don't add empty chunks
        if chunk_text:
            # Append the chunk with its metadata to the list
            chunks.append({
                "text": chunk_text,  # The chunk of text
                "index": len(chunks),  # The index of the chunk
                "start_pos": i,  # The starting position of the chunk in the original text
                "end_pos": i + len(chunk_text)  # The ending position of the chunk in the original text
            })
    
    # Print the number of chunks created
    print(f"Created {len(chunks)} text chunks")
    
    return chunks  # Return the list of chunks

# %% [markdown]
# ## Creating Embeddings

# %%
def create_embeddings(texts, model="BAAI/bge-en-icl"):
    """
    Create embeddings for the given texts.
    
    Args:
        texts (List[str]): Input texts
        model (str): Embedding model name
        
    Returns:
        List[List[float]]: Embedding vectors
    """
    # Handle empty input
    if not texts:
        return []
        
    # Process in batches if needed (OpenAI API limits)
    batch_size = 100
    all_embeddings = []
    
    # Iterate over the input texts in batches
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i + batch_size]  # Get the current batch of texts
        
        # Create embeddings for the current batch
        response = client.embeddings.create(
            model=model,
            input=batch
        )
        
        # Extract embeddings from the response
        batch_embeddings = [item.embedding for item in response.data]
        all_embeddings.extend(batch_embeddings)  # Add the batch embeddings to the list
    
    return all_embeddings  # Return all embeddings

# %% [markdown]
# ## Knowledge Graph Construction

# %%
def extract_concepts(text):
    """
    Extract key concepts from text using OpenAI's API.
    
    Args:
        text (str): Text to extract concepts from
        
    Returns:
        List[str]: List of concepts
    """
    # System message to instruct the model on what to do
    system_message = """Extract key concepts and entities from the provided text.
Return ONLY a list of 5-10 key terms, entities, or concepts that are most important in this text.
Format your response as a JSON object."""

    # Make a request to the OpenAI API
    response = client.chat.completions.create(
        model="meta-llama/Llama-3.2-3B-Instruct",
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": f"Extract key concepts from:\n\n{text[:10000]}"}  # Limit for API
        ],
        temperature=0.0,
        response_format={"type": "json_object"}
    )

    try:
        # Parse concepts from the response
        concepts_json = json.loads(response.choices[0].message.content)
        concepts = concepts_json.get("concepts", [])
        if not concepts and "concepts" not in concepts_json:
            # Try to get any array in the response
            for key, value in concepts_json.items():
                if isinstance(value, list):
                    concepts = value
                    break
        return concepts
    except (json.JSONDecodeError, AttributeError):
        # Fallback if JSON parsing fails
        content = response.choices[0].message.content
        # Try to extract anything that looks like a list
        matches = re.findall(r'\[(.*?)\]', content, re.DOTALL)
        if matches:
            items = re.findall(r'"([^"]*)"', matches[0])
            return items
        return []

# %%
def build_knowledge_graph(chunks):
    """
    Build a knowledge graph from text chunks.
    
    Args:
        chunks (List[Dict]): List of text chunks with metadata
        
    Returns:
        Tuple[nx.Graph, List[np.ndarray]]: The knowledge graph and chunk embeddings
    """
    print("Building knowledge graph...")
    
    # Create a graph
    graph = nx.Graph()
    
    # Extract chunk texts
    texts = [chunk["text"] for chunk in chunks]
    
    # Create embeddings for all chunks
    print("Creating embeddings for chunks...")
    embeddings = create_embeddings(texts)
    
    # Add nodes to the graph
    print("Adding nodes to the graph...")
    for i, chunk in enumerate(chunks):
        # Extract concepts from the chunk
        
        concepts = extract_concepts(chunk["text"])
        print(f"Extracted concepts for chunk {i+1}/{len(chunks)} are {concepts}")

        # Add node with attributes
        graph.add_node(i, 
                      text=chunk["text"], 
                      concepts=concepts,
                      embedding=embeddings[i])
    
    # Connect nodes based on shared concepts
    print("Creating edges between nodes...")
    for i in range(len(chunks)):
        node_concepts = set(graph.nodes[i]["concepts"])
        print(f"Node concept is {node_concepts}")
        
        for j in range(i + 1, len(chunks)):
            # Calculate concept overlap
            other_concepts = set(graph.nodes[j]["concepts"])
            shared_concepts = node_concepts.intersection(other_concepts)
            
            # If they share concepts, add an edge
            if shared_concepts:
                # Calculate semantic similarity using embeddings
                similarity = np.dot(embeddings[i], embeddings[j]) / (np.linalg.norm(embeddings[i]) * np.linalg.norm(embeddings[j]))
                
                # Calculate edge weight based on concept overlap and semantic similarity
                concept_score = len(shared_concepts) / min(len(node_concepts), len(other_concepts))
                edge_weight = 0.7 * similarity + 0.3 * concept_score
                
                # Only add edges with significant relationship
                if edge_weight > 0.6:
                    graph.add_edge(i, j, 
                                  weight=edge_weight,
                                  similarity=similarity,
                                  shared_concepts=list(shared_concepts))
    
    print(f"Knowledge graph built with {graph.number_of_nodes()} nodes and {graph.number_of_edges()} edges")
    return graph, embeddings

# %% [markdown]
# ## Graph Traversal and Query Processing

# %%
def traverse_graph(query, graph, embeddings, top_k=5, max_depth=3):
    """
    Traverse the knowledge graph to find relevant information for the query.
    
    Args:
        query (str): The user's question
        graph (nx.Graph): The knowledge graph
        embeddings (List): List of node embeddings
        top_k (int): Number of initial nodes to consider
        max_depth (int): Maximum traversal depth
        
    Returns:
        List[Dict]: Relevant information from graph traversal
    """
    print(f"Traversing graph for query: {query}")
    
    # Get query embedding
    query_embedding = create_embeddings(query)
    
    # Calculate similarity between query and all nodes
    similarities = []
    for i, node_embedding in enumerate(embeddings):
        similarity = np.dot(query_embedding, node_embedding) / (np.linalg.norm(query_embedding) * np.linalg.norm(node_embedding))
        similarities.append((i, similarity))
    
    # Sort by similarity (descending)
    similarities.sort(key=lambda x: x[1], reverse=True)
    
    # Get top-k most similar nodes as starting points
    starting_nodes = [node for node, _ in similarities[:top_k]]
    print(f"Starting traversal from {len(starting_nodes)} nodes")
    
    # Initialize traversal
    visited = set()  # Set to keep track of visited nodes
    traversal_path = []  # List to store the traversal path
    results = []  # List to store the results
    
    # Use a priority queue for traversal
    queue = []
    for node in starting_nodes:
        heapq.heappush(queue, (-similarities[node][1], node))  # Negative for max-heap
    
    # Traverse the graph using a modified breadth-first search with priority
    while queue and len(results) < (top_k * 3):  # Limit results to top_k * 3
        _, node = heapq.heappop(queue)
        
        if node in visited:
            continue
        
        # Mark as visited
        visited.add(node)
        traversal_path.append(node)
        
        # Add current node's text to results
        results.append({
            "text": graph.nodes[node]["text"],
            "concepts": graph.nodes[node]["concepts"],
            "node_id": node
        })
        
        # Explore neighbors if we haven't reached max depth
        if len(traversal_path) < max_depth:
            neighbors = [(neighbor, graph[node][neighbor]["weight"]) 
                        for neighbor in graph.neighbors(node)
                        if neighbor not in visited]
            
            # Add neighbors to queue based on edge weight
            for neighbor, weight in sorted(neighbors, key=lambda x: x[1], reverse=True):
                heapq.heappush(queue, (-weight, neighbor))
    
    print(f"Graph traversal found {len(results)} relevant chunks")
    return results, traversal_path

# %% [markdown]
# ## Response Generation

# %%
def generate_response(query, context_chunks):
    """
    Generate a response using the retrieved context.
    
    Args:
        query (str): The user's question
        context_chunks (List[Dict]): Relevant chunks from graph traversal
        
    Returns:
        str: Generated response
    """
    # Extract text from each chunk in the context
    context_texts = [chunk["text"] for chunk in context_chunks]
    
    # Combine the extracted texts into a single context string, separated by "---"
    combined_context = "\n\n---\n\n".join(context_texts)
    
    # Define the maximum allowed length for the context (OpenAI limit)
    max_context = 14000
    
    # Truncate the combined context if it exceeds the maximum length
    if len(combined_context) > max_context:
        combined_context = combined_context[:max_context] + "... [truncated]"
    
    # Define the system message to guide the AI assistant
    system_message = """You are a helpful AI assistant. Answer the user's question based on the provided context.
If the information is not in the context, say so. Refer to specific parts of the context in your answer when possible."""

    # Generate the response using the OpenAI API
    response = client.chat.completions.create(
        model="meta-llama/Llama-3.2-3B-Instruct",  # Specify the model to use
        messages=[
            {"role": "system", "content": system_message},  # System message to guide the assistant
            {"role": "user", "content": f"Context:\n{combined_context}\n\nQuestion: {query}"}  # User message with context and query
        ],
        temperature=0.2  # Set the temperature for response generation
    )
    
    # Return the generated response content
    return response.choices[0].message.content

# %% [markdown]
# ## Visualization

# %%
def visualize_graph_traversal(graph, traversal_path):
    """
    Visualize the knowledge graph and the traversal path.
    
    Args:
        graph (nx.Graph): The knowledge graph
        traversal_path (List): List of nodes in traversal order
    """
    plt.figure(figsize=(12, 10))  # Set the figure size
    
    # Define node colors, default to light blue
    node_color = ['lightblue'] * graph.number_of_nodes()
    
    # Highlight traversal path nodes in light green
    for node in traversal_path:
        node_color[node] = 'lightgreen'
    
    # Highlight start node in green and end node in red
    if traversal_path:
        node_color[traversal_path[0]] = 'green'
        node_color[traversal_path[-1]] = 'red'
    
    # Create positions for all nodes using spring layout
    pos = nx.spring_layout(graph, k=0.5, iterations=50, seed=42)
    
    # Draw the graph nodes
    nx.draw_networkx_nodes(graph, pos, node_color=node_color, node_size=500, alpha=0.8)
    
    # Draw edges with width proportional to weight
    for u, v, data in graph.edges(data=True):
        weight = data.get('weight', 1.0)
        nx.draw_networkx_edges(graph, pos, edgelist=[(u, v)], width=weight*2, alpha=0.6)
    
    # Draw traversal path with red dashed lines
    traversal_edges = [(traversal_path[i], traversal_path[i+1]) 
                      for i in range(len(traversal_path)-1)]
    
    nx.draw_networkx_edges(graph, pos, edgelist=traversal_edges, 
                          width=3, alpha=0.8, edge_color='red', 
                          style='dashed', arrows=True)
    
    # Add labels with the first concept for each node
    labels = {}
    for node in graph.nodes():
        concepts = graph.nodes[node]['concepts']
        label = concepts[0] if concepts else f"Node {node}"
        labels[node] = f"{node}: {label}"
    
    nx.draw_networkx_labels(graph, pos, labels=labels, font_size=8)
    
    plt.title("Knowledge Graph with Traversal Path")  # Set the plot title
    plt.axis('off')  # Turn off the axis
    plt.tight_layout()  # Adjust layout
    plt.show()  # Display the plot

# %% [markdown]
# ## Complete Graph RAG Pipeline

# %%
def graph_rag_pipeline(pdf_path, query, chunk_size=1000, chunk_overlap=200, top_k=3):
    """
    Complete Graph RAG pipeline from document to answer.
    
    Args:
        pdf_path (str): Path to the PDF document
        query (str): The user's question
        chunk_size (int): Size of text chunks
        chunk_overlap (int): Overlap between chunks
        top_k (int): Number of top nodes to consider for traversal
        
    Returns:
        Dict: Results including answer and graph visualization data
    """
    # Extract text from the PDF document
    text = extract_text_from_pdf(pdf_path)
    
    # Split the extracted text into overlapping chunks
    chunks = chunk_text(text, chunk_size, chunk_overlap)
    
    # Build a knowledge graph from the text chunks
    graph, embeddings = build_knowledge_graph(chunks)
    
    # Traverse the knowledge graph to find relevant information for the query
    relevant_chunks, traversal_path = traverse_graph(query, graph, embeddings, top_k)
    
    # Generate a response based on the query and the relevant chunks
    response = generate_response(query, relevant_chunks)
    
    # Visualize the graph traversal path
    visualize_graph_traversal(graph, traversal_path)
    
    # Return the query, response, relevant chunks, traversal path, and the graph
    return {
        "query": query,
        "response": response,
        "relevant_chunks": relevant_chunks,
        "traversal_path": traversal_path,
        "graph": graph
    }

# %% [markdown]
# ## Evaluation Function

# %%
def compare_with_reference(response, reference, query):
    """
    Compare generated response with reference answer.
    
    Args:
        response (str): Generated response
        reference (str): Reference answer
        query (str): Original query
        
    Returns:
        str: Comparison analysis
    """
    # System message to instruct the model on how to compare the responses
    system_message = """Compare the AI-generated response with the reference answer.
Evaluate based on: correctness, completeness, and relevance to the query.
Provide a brief analysis (2-3 sentences) of how well the generated response matches the reference."""

    # Construct the prompt with the query, AI-generated response, and reference answer
    prompt = f"""
Query: {query}

AI-generated response:
{response}

Reference answer:
{reference}

How well does the AI response match the reference?
"""

    # Make a request to the OpenAI API to generate the comparison analysis
    comparison = client.chat.completions.create(
        model="meta-llama/Llama-3.2-3B-Instruct",
        messages=[
            {"role": "system", "content": system_message},  # System message to guide the assistant
            {"role": "user", "content": prompt}  # User message with the prompt
        ],
        temperature=0.0  # Set the temperature for response generation
    )
    
    # Return the generated comparison analysis
    return comparison.choices[0].message.content

# %%
def evaluate_graph_rag(pdf_path, test_queries, reference_answers=None):
    """
    Evaluate Graph RAG on multiple test queries.
    
    Args:
        pdf_path (str): Path to the PDF document
        test_queries (List[str]): List of test queries
        reference_answers (List[str], optional): Reference answers for comparison
        
    Returns:
        Dict: Evaluation results
    """
    # Extract text from PDF
    text = extract_text_from_pdf(pdf_path)
    
    # Split text into chunks
    chunks = chunk_text(text)
    
    # Build knowledge graph (do this once for all queries)
    graph, embeddings = build_knowledge_graph(chunks)
    
    results = []
    
    for i, query in enumerate(test_queries):
        print(f"\n\n=== Evaluating Query {i+1}/{len(test_queries)} ===")
        print(f"Query: {query}")
        
        # Traverse graph to find relevant information
        relevant_chunks, traversal_path = traverse_graph(query, graph, embeddings)
        
        # Generate response
        response = generate_response(query, relevant_chunks)
        
        # Compare with reference answer if available
        reference = None
        comparison = None
        if reference_answers and i < len(reference_answers):
            reference = reference_answers[i]
            comparison = compare_with_reference(response, reference, query)
        
        # Append results for the current query
        results.append({
            "query": query,
            "response": response,
            "reference_answer": reference,
            "comparison": comparison,
            "traversal_path_length": len(traversal_path),
            "relevant_chunks_count": len(relevant_chunks)
        })
        
        # Display results
        print(f"\nResponse: {response}\n")
        if comparison:
            print(f"Comparison: {comparison}\n")
    
    # Return evaluation results and graph statistics
    return {
        "results": results,
        "graph_stats": {
            "nodes": graph.number_of_nodes(),
            "edges": graph.number_of_edges(),
            "avg_degree": sum(dict(graph.degree()).values()) / graph.number_of_nodes()
        }
    }

# %% [markdown]
# ## Evaluation of Graph RAG on a Sample PDF Document

# %%
# Path to the PDF document containing AI information
pdf_path = "data/AI_Information.pdf"

# Define an AI-related query for testing Graph RAG
query = "What are the key applications of transformers in natural language processing?"

# Execute the Graph RAG pipeline to process the document and answer the query
results = graph_rag_pipeline(pdf_path, query)

# Print the response generated from the Graph RAG system
print("\n=== ANSWER ===")
print(results["response"])

# Define a test query and reference answer for formal evaluation
test_queries = [
    "How do transformers handle sequential data compared to RNNs?"
]

# Reference answer for evaluation purposes
reference_answers = [
    "Transformers handle sequential data differently from RNNs by using self-attention mechanisms instead of recurrent connections. This allows transformers to process all tokens in parallel rather than sequentially, capturing long-range dependencies more efficiently and enabling better parallelization during training. Unlike RNNs, transformers don't suffer from vanishing gradient problems with long sequences."
]

# Run formal evaluation of the Graph RAG system with the test query
evaluation = evaluate_graph_rag(pdf_path, test_queries, reference_answers)

# Print evaluation summary statistics
print("\n=== EVALUATION SUMMARY ===")
print(f"Graph nodes: {evaluation['graph_stats']['nodes']}")
print(f"Graph edges: {evaluation['graph_stats']['edges']}")
for i, result in enumerate(evaluation['results']):
    print(f"\nQuery {i+1}: {result['query']}")
    print(f"Path length: {result['traversal_path_length']}")
    print(f"Chunks used: {result['relevant_chunks_count']}")
# Out:
# Extracting text from data/AI_Information.pdf...
# Created 42 text chunks
# Building knowledge graph...
# Creating embeddings for chunks...
# Adding nodes to the graph...
# Extracted concepts for chunk 1/42 are ['Artificial Intelligence', 'Intelligent Beings', 'Computing Power', 'Data Availability', 'Reasoning', 'Generalization', 'Learning', 'Dartmouth Workshop', 'Problem-Solving', 'Symbolic Methods']
# Extracted concepts for chunk 2/42 are ['Artificial Intelligence', 'Machine Learning', 'Deep Learning', 'Expert Systems', 'Neural Networks', 'Self-Driving Cars', 'Virtual Assistants', 'Bias', 'Ethics']
# Extracted concepts for chunk 3/42 are ['Artificial Intelligence', 'Machine Learning', 'Bias', 'Job Displacement', 'Supervised Learning', 'Unsupervised Learning']
# Extracted concepts for chunk 4/42 are ['Unsupervised Learning', 'Clustering', 'Dimensionality Reduction', 'Reinforcement Learning', 'Deep Learning', 'Artificial Neural Networks']
# Extracted concepts for chunk 5/42 are ['Deep Learning', 'Convolutional Neural Networks (CNNs)', 'Recurrent Neural Networks (RNNs)', 'Natural Language Processing (NLP)', 'Image Recognition', 'Natural Language Processing (NLP)', 'Speech Recognition', 'Object Detection', 'Facial Recognition', 'Medical Image Analysis']
# Extracted concepts for chunk 6/42 are ['Natural Language Processing (NLP)', 'Artificial Intelligence (AI)', 'Computer Vision', 'Chatbots', 'Machine Translation', 'Text Summarization', 'Sentiment Analysis', 'Computer Vision', 'Object Detection', 'Image Segmentation', 'Facial Recognition', 'Healthcare', 'Medical Diagnosis', 'Personalized Medicine', 'Robotic Surgery']
# Extracted concepts for chunk 7/42 are ['Artificial Intelligence (AI)', 'Medical Diagnosis', 'Personalized Medicine', 'Robotic Surgery', 'Fraud Detection', 'Algorithmic Trading', 'Risk Management', 'Customer Service', 'Self-Driving Cars', 'Traffic Optimization', 'Logistics Management', 'Supply Chain Optimization', 'Inventory Management', 'Customer Service Chatbots']
# Extracted concepts for chunk 8/42 are ['AI', 'Customer Data', 'Demand Prediction', 'Personalization', 'Supply Chain Optimization', 'Manufacturing', 'Predictive Maintenance', 'Quality Control', 'Process Optimization', 'Robotics']
# Extracted concepts for chunk 9/42 are ['AI algorithms', 'Cybersecurity', 'Bias and Fairness', 'Transparency and Explainability', 'Ethical Implications of AI', 'Deep Learning Models', 'User Engagement', 'Network Traffic', 'Vulnerabilities', 'Threat Detection']
# Extracted concepts for chunk 10/42 are ['Transparency', 'Explainability', 'Privacy', 'Security', 'Job Displacement', 'Autonomy', 'Accountability', 'Ethics', 'AI Development', 'Data Security']
# Extracted concepts for chunk 11/42 are ['Explainable AI (XAI)', 'Accountability', 'Control', 'Unintended Consequences', 'AI at the Edge', 'Weaponization of AI', 'International Regulations', 'Ethical Frameworks', 'Autonomous Weapons Systems']
# Extracted concepts for chunk 12/42 are ['AI at the Edge', 'Quantum Computing and AI', 'Human-AI Collaboration', 'AI for Social Good', 'Trust and Accountability', 'Decision-making', 'Artificial Intelligence', 'Augmentation', 'Productivity', 'Collaboration']
# Extracted concepts for chunk 13/42 are ['Transformative Technology', 'Responsible Development', 'Thoughtful Governance']
# Extracted concepts for chunk 14/42 are ['Artificial Intelligence (AI)', 'Robotics', 'Integration of AI and Robotics', 'Cognitive Abilities', 'Physical Capabilities', 'Industrial Robots', 'Service Robots', 'Cobots', 'Manufacturing', 'Healthcare']
# Extracted concepts for chunk 15/42 are ['cobots', 'Service Robots', 'Surgical Robots', 'Exploration Robots', 'Robot Learning', 'Imitation Learning', 'Reinforcement Learning']
# Extracted concepts for chunk 16/42 are ['Reinforcement Learning', 'Robot Navigation', 'SLAM (Simultaneous Localization and Mapping)', 'Computer Vision', 'Robotics', 'Autonomous Navigation', 'Trial and Error', 'Reward-based Learning', 'Robot Perception', 'AI in Business']
# Extracted concepts for chunk 17/42 are ['Artificial Intelligence', 'Object Recognition', 'Scene Understanding', 'Obstacle Avoidance', 'Customer Relationship Management', 'Supply Chain Management', 'Automation', 'Data Analysis', 'Decision-Making', 'Business Operations']
# Extracted concepts for chunk 18/42 are ['Artificial Intelligence (AI)', 'Supply Chain Management', 'Talent Acquisition', 'Employee Onboarding', 'Performance Management', 'Training', 'Talent Retention', 'Customer Data Analysis', 'Marketing Campaigns', 'Fraud Detection', 'Risk Management', 'Algorithmic Trading']
# Extracted concepts for chunk 19/42 are ['AI-powered systems', 'Algorithmic trading', 'Customer service', 'Automation', 'Job displacement', 'Reskilling', 'Upskilling', 'Human-AI collaboration', 'Artificial intelligence', 'Future of work']
# Extracted concepts for chunk 20/42 are ['AI', 'Collaboration', 'Job Roles', 'Ethics', 'Creativity', 'Innovation']
# Extracted concepts for chunk 21/42 are ['AI-Generated Art', 'AI in Music Composition', 'AI in Writing and Content Creation', 'AI-Driven Innovation', 'Artificial Intelligence', 'Design Processes', 'Scientific Discovery', 'Innovation', 'Content Generation', 'Creative Expression']
# Extracted concepts for chunk 22/42 are ['AI-powered tools', 'Personalized Learning', 'Adaptive Assessments', 'Virtual Tutors and Learning Assistants', 'AI in Education', 'Machine Learning', 'Data Analysis', 'Research and Development', 'Product Design', 'Problem-Solving']
# Extracted concepts for chunk 23/42 are ['Personalized Learning', 'Automated Grading', 'Educational Data Mining', 'Artificial Intelligence (AI)', 'Medical Diagnosis', 'Medical Treatment', 'Drug Discovery', 'Healthcare', 'Learning Outcomes', 'Instructional Strategies']
# Extracted concepts for chunk 24/42 are ['Artificial Intelligence', 'Medical Imaging', 'Personalized Medicine', 'Drug Discovery', 'Robotic Surgery', 'Healthcare Administration']
# Extracted concepts for chunk 25/42 are ['Artificial Intelligence (AI)', 'Healthcare Administration', 'Cybersecurity', 'Threat Detection', 'Anomaly Detection', 'Fraud Detection']
# Extracted concepts for chunk 26/42 are ['Artificial Intelligence', 'Fraud Detection', 'Vulnerability Management', 'Incident Response', 'Cybersecurity', 'AI-powered systems', 'Security Incidents', 'Societal Challenges', 'Climate Change', 'Poverty', 'Healthcare']
# Extracted concepts for chunk 27/42 are ['AI for Social Good', 'Ethical Considerations', 'Public Perception and Trust', 'Addressing Societal Challenges', 'Climate Change', 'Poverty', 'Healthcare Disparities', 'Sustainable Development', 'Resource Management', 'Decision-Making']
# Extracted concepts for chunk 28/42 are ['AI', 'Privacy', 'Human Rights', 'Public Perception', 'Trust', 'Global Collaboration', 'Urban Planning', 'Smart Cities', 'Smart Transportation']
# Extracted concepts for chunk 29/42 are ['Smart Transportation', 'AI-powered systems', 'Energy Management', 'Public Safety and Security', 'Environmental Monitoring', 'Autonomous Vehicles', 'Renewable Energy Sources', 'Grid Stability', 'Energy Efficiency', 'Crime Prevention']
# Extracted concepts for chunk 30/42 are ['Environmental Monitoring', 'AI-powered environmental monitoring systems', 'Deep Learning', 'Explainable AI (XAI)', 'Neuroscience', 'AI Research', 'Air Quality', 'Water Quality', 'Pollution Detection', 'Environmental Protection']
# Extracted concepts for chunk 31/42 are ['AI and Neuroscience', 'AI Safety and Security', 'Human-Centered AI', 'Generative AI and Creativity', 'Accountability']
# Extracted concepts for chunk 32/42 are ['Generative Adversarial Networks (GANs)', 'Transformers', 'Artistic Expression', 'Collaborative AI', 'AI in Music', 'AI in Sound Design', 'AI in Visual Arts', 'AI-Driven Creativity', 'Artistic Collaboration', 'Creative Process']
# Extracted concepts for chunk 33/42 are ['AI in Visual Arts and Design', 'AI-powered tools', 'Artificial Intelligence', 'Interactive Media', 'Climate Change Mitigation', 'Precision Agriculture', 'Audio Mixing and Mastering', 'Virtual Reality', 'Video Games', 'Design Processes']
# Extracted concepts for chunk 34/42 are ['AI-powered systems', 'Precision Agriculture', 'Wildlife Conservation', 'Environmental Monitoring', 'Disaster Response', 'Carbon Capture and Storage', 'Climate Impacts', 'Data Analysis', 'Resource Optimization', 'Food Security']
# Extracted concepts for chunk 35/42 are ['Artificial Intelligence (AI)', 'Disaster Response', 'Environmental Policy', 'Government Policy', 'Regulation of AI', 'AI Strategy', 'Funding for AI Research', 'Ethics in AI', 'Innovation', 'Responsible AI Practices']
# Extracted concepts for chunk 36/42 are ['AI', 'Bias', 'Transparency', 'Privacy', 'Safety', 'Ethics', 'Innovation', 'International Cooperation', 'Public Engagement', 'Education']
# Extracted concepts for chunk 37/42 are ['Ethical AI', 'AI Ethics', 'Bias in AI', 'Transparency in AI', 'Explainability in AI', 'Data Protection', 'Respect for Human Rights', 'Privacy', 'Non-Discrimination', 'Beneficence']
# Extracted concepts for chunk 38/42 are ['Explainable AI (XAI)', 'Privacy and Data Protection', 'Accountability and Responsibility', 'Transparency and Explainability', 'Robustness and Reliability']
# Extracted concepts for chunk 39/42 are ['Trust in AI', 'Robustness', 'Reliability', 'User Control', 'Agency', 'Ethical Design', 'Ethical Development', 'Public Engagement', 'Education', 'Decision-Making Processes']
# Extracted concepts for chunk 40/42 are ['Building Trust', 'Ethical Impact Assessments', 'Public Engagement', 'Public Awareness Campaigns', 'Responsible AI Development', 'Continued Research and Innovation', 'Basic Research', 'Applied Research', 'Ethical Guidelines', 'Ethical Standards']
# Extracted concepts for chunk 41/42 are ['Responsible AI', 'Global Collaboration', 'Ethics in AI', 'Education and Workforce Development', 'Human-Centered Approach', 'Artificial Intelligence (AI)']
# Extracted concepts for chunk 42/42 are ['STEM education', 'reskilling', 'upskilling', 'lifelong learning', 'Human-Centered Approach', 'AI', 'human capabilities', 'well-being', 'human values', 'responsible AI development']
# Creating edges between nodes...
# Node concept is {'Reasoning', 'Data Availability', 'Dartmouth Workshop', 'Generalization', 'Computing Power', 'Intelligent Beings', 'Problem-Solving', 'Symbolic Methods', 'Learning', 'Artificial Intelligence'}
# Node concept is {'Virtual Assistants', 'Machine Learning', 'Expert Systems', 'Deep Learning', 'Ethics', 'Neural Networks', 'Bias', 'Self-Driving Cars', 'Artificial Intelligence'}
# Node concept is {'Machine Learning', 'Supervised Learning', 'Job Displacement', 'Unsupervised Learning', 'Bias', 'Artificial Intelligence'}
# Node concept is {'Reinforcement Learning', 'Deep Learning', 'Unsupervised Learning', 'Dimensionality Reduction', 'Clustering', 'Artificial Neural Networks'}
# Node concept is {'Recurrent Neural Networks (RNNs)', 'Medical Image Analysis', 'Speech Recognition', 'Object Detection', 'Deep Learning', 'Facial Recognition', 'Convolutional Neural Networks (CNNs)', 'Image Recognition', 'Natural Language Processing (NLP)'}
# Node concept is {'Machine Translation', 'Computer Vision', 'Chatbots', 'Object Detection', 'Healthcare', 'Text Summarization', 'Facial Recognition', 'Image Segmentation', 'Sentiment Analysis', 'Medical Diagnosis', 'Robotic Surgery', 'Personalized Medicine', 'Natural Language Processing (NLP)', 'Artificial Intelligence (AI)'}
# Node concept is {'Logistics Management', 'Algorithmic Trading', 'Fraud Detection', 'Traffic Optimization', 'Customer Service Chatbots', 'Customer Service', 'Risk Management', 'Supply Chain Optimization', 'Robotic Surgery', 'Medical Diagnosis', 'Self-Driving Cars', 'Personalized Medicine', 'Inventory Management', 'Artificial Intelligence (AI)'}
# Node concept is {'Manufacturing', 'Predictive Maintenance', 'Robotics', 'Process Optimization', 'AI', 'Quality Control', 'Personalization', 'Demand Prediction', 'Customer Data', 'Supply Chain Optimization'}
# Node concept is {'User Engagement', 'Vulnerabilities', 'AI algorithms', 'Deep Learning Models', 'Network Traffic', 'Ethical Implications of AI', 'Threat Detection', 'Transparency and Explainability', 'Bias and Fairness', 'Cybersecurity'}
# Node concept is {'Data Security', 'Explainability', 'Accountability', 'Privacy', 'AI Development', 'Job Displacement', 'Autonomy', 'Ethics', 'Transparency', 'Security'}
# Node concept is {'Accountability', 'Explainable AI (XAI)', 'Ethical Frameworks', 'Weaponization of AI', 'International Regulations', 'Unintended Consequences', 'Control', 'Autonomous Weapons Systems', 'AI at the Edge'}
# Node concept is {'Human-AI Collaboration', 'Productivity', 'Collaboration', 'Augmentation', 'Decision-making', 'Artificial Intelligence', 'AI at the Edge', 'Quantum Computing and AI', 'AI for Social Good', 'Trust and Accountability'}
# Node concept is {'Responsible Development', 'Transformative Technology', 'Thoughtful Governance'}
# Node concept is {'Manufacturing', 'Robotics', 'Healthcare', 'Cognitive Abilities', 'Industrial Robots', 'Physical Capabilities', 'Artificial Intelligence (AI)', 'Cobots', 'Service Robots', 'Integration of AI and Robotics'}
# Node concept is {'cobots', 'Surgical Robots', 'Reinforcement Learning', 'Robot Learning', 'Exploration Robots', 'Service Robots', 'Imitation Learning'}
# Node concept is {'Robot Navigation', 'Robotics', 'Trial and Error', 'Computer Vision', 'Robot Perception', 'Reinforcement Learning', 'AI in Business', 'Reward-based Learning', 'SLAM (Simultaneous Localization and Mapping)', 'Autonomous Navigation'}
# Node concept is {'Business Operations', 'Customer Relationship Management', 'Decision-Making', 'Automation', 'Data Analysis', 'Scene Understanding', 'Object Recognition', 'Supply Chain Management', 'Obstacle Avoidance', 'Artificial Intelligence'}
# Node concept is {'Talent Retention', 'Talent Acquisition', 'Customer Data Analysis', 'Algorithmic Trading', 'Fraud Detection', 'Marketing Campaigns', 'Training', 'Risk Management', 'Performance Management', 'Supply Chain Management', 'Employee Onboarding', 'Artificial Intelligence (AI)'}
# Node concept is {'Algorithmic trading', 'Automation', 'AI-powered systems', 'Customer service', 'Upskilling', 'Job displacement', 'Human-AI collaboration', 'Future of work', 'Reskilling', 'Artificial intelligence'}
# Node concept is {'Creativity', 'AI', 'Job Roles', 'Collaboration', 'Ethics', 'Innovation'}
# Node concept is {'AI in Writing and Content Creation', 'Scientific Discovery', 'AI-Generated Art', 'Design Processes', 'AI-Driven Innovation', 'Content Generation', 'Creative Expression', 'Innovation', 'Artificial Intelligence', 'AI in Music Composition'}
# Node concept is {'AI-powered tools', 'Machine Learning', 'Product Design', 'AI in Education', 'Personalized Learning', 'Data Analysis', 'Virtual Tutors and Learning Assistants', 'Research and Development', 'Problem-Solving', 'Adaptive Assessments'}
# Node concept is {'Educational Data Mining', 'Learning Outcomes', 'Healthcare', 'Medical Treatment', 'Personalized Learning', 'Instructional Strategies', 'Drug Discovery', 'Medical Diagnosis', 'Automated Grading', 'Artificial Intelligence (AI)'}
# Node concept is {'Medical Imaging', 'Drug Discovery', 'Healthcare Administration', 'Robotic Surgery', 'Personalized Medicine', 'Artificial Intelligence'}
# Node concept is {'Fraud Detection', 'Threat Detection', 'Healthcare Administration', 'Anomaly Detection', 'Cybersecurity', 'Artificial Intelligence (AI)'}
# Node concept is {'Poverty', 'Security Incidents', 'Incident Response', 'Healthcare', 'Fraud Detection', 'AI-powered systems', 'Vulnerability Management', 'Societal Challenges', 'Climate Change', 'Cybersecurity', 'Artificial Intelligence'}
# Node concept is {'Healthcare Disparities', 'Poverty', 'Resource Management', 'Public Perception and Trust', 'Addressing Societal Challenges', 'Sustainable Development', 'Decision-Making', 'Climate Change', 'Ethical Considerations', 'AI for Social Good'}
# Node concept is {'Public Perception', 'Urban Planning', 'AI', 'Privacy', 'Global Collaboration', 'Smart Cities', 'Trust', 'Smart Transportation', 'Human Rights'}
# Node concept is {'Energy Efficiency', 'Autonomous Vehicles', 'AI-powered systems', 'Crime Prevention', 'Public Safety and Security', 'Renewable Energy Sources', 'Grid Stability', 'Environmental Monitoring', 'Smart Transportation', 'Energy Management'}
# Node concept is {'AI-powered environmental monitoring systems', 'Pollution Detection', 'Water Quality', 'Explainable AI (XAI)', 'Air Quality', 'Deep Learning', 'Neuroscience', 'AI Research', 'Environmental Protection', 'Environmental Monitoring'}
# Node concept is {'Generative AI and Creativity', 'Accountability', 'AI and Neuroscience', 'Human-Centered AI', 'AI Safety and Security'}
# Node concept is {'Creative Process', 'Transformers', 'Artistic Collaboration', 'AI in Visual Arts', 'Generative Adversarial Networks (GANs)', 'Collaborative AI', 'AI-Driven Creativity', 'AI in Music', 'AI in Sound Design', 'Artistic Expression'}
# Node concept is {'AI-powered tools', 'Climate Change Mitigation', 'Audio Mixing and Mastering', 'Virtual Reality', 'Video Games', 'Design Processes', 'Interactive Media', 'AI in Visual Arts and Design', 'Precision Agriculture', 'Artificial Intelligence'}
# Node concept is {'Wildlife Conservation', 'Carbon Capture and Storage', 'AI-powered systems', 'Food Security', 'Data Analysis', 'Climate Impacts', 'Resource Optimization', 'Disaster Response', 'Environmental Monitoring', 'Precision Agriculture'}
# Node concept is {'Environmental Policy', 'Ethics in AI', 'Government Policy', 'Artificial Intelligence (AI)', 'Funding for AI Research', 'AI Strategy', 'Disaster Response', 'Responsible AI Practices', 'Innovation', 'Regulation of AI'}
# Node concept is {'Safety', 'International Cooperation', 'AI', 'Privacy', 'Ethics', 'Education', 'Transparency', 'Bias', 'Public Engagement', 'Innovation'}
# Node concept is {'Bias in AI', 'AI Ethics', 'Respect for Human Rights', 'Privacy', 'Explainability in AI', 'Data Protection', 'Ethical AI', 'Beneficence', 'Non-Discrimination', 'Transparency in AI'}
# Node concept is {'Explainable AI (XAI)', 'Robustness and Reliability', 'Transparency and Explainability', 'Accountability and Responsibility', 'Privacy and Data Protection'}
# Node concept is {'Decision-Making Processes', 'Agency', 'Trust in AI', 'User Control', 'Robustness', 'Ethical Development', 'Reliability', 'Ethical Design', 'Public Engagement', 'Education'}
# Node concept is {'Ethical Guidelines', 'Ethical Impact Assessments', 'Responsible AI Development', 'Continued Research and Innovation', 'Public Awareness Campaigns', 'Applied Research', 'Public Engagement', 'Basic Research', 'Ethical Standards', 'Building Trust'}
# Node concept is {'Ethics in AI', 'Global Collaboration', 'Human-Centered Approach', 'Education and Workforce Development', 'Responsible AI', 'Artificial Intelligence (AI)'}
# Node concept is {'reskilling', 'STEM education', 'AI', 'well-being', 'upskilling', 'Human-Centered Approach', 'human values', 'human capabilities', 'responsible AI development', 'lifelong learning'}
# Knowledge graph built with 42 nodes and 65 edges
# Traversing graph for query: What are the key applications of transformers in natural language processing?
# Starting traversal from 3 nodes
# Graph traversal found 5 relevant chunks
# === ANSWER ===
# There is no mention of transformers in the provided context. The context only discusses various machine learning and deep learning techniques, including clustering, dimensionality reduction, reinforcement learning, deep learning, convolutional neural networks (CNNs), recurrent neural networks (RNNs), natural language processing (NLP), computer vision, and their applications in different domains.
# Extracting text from data/AI_Information.pdf...
# Created 42 text chunks
# Building knowledge graph...
# Creating embeddings for chunks...
# Adding nodes to the graph...
# Extracted concepts for chunk 1/42 are ['Artificial Intelligence', 'Intelligent Systems', 'Computing Power', 'Data Availability', 'Reasoning', 'Generalization', 'Learning', 'Dartmouth Workshop', 'Symbolic Methods', 'Problem-Solving']
# Extracted concepts for chunk 2/42 are ['Artificial Intelligence', 'Machine Learning', 'Neural Networks', 'Deep Learning', 'Expert Systems', 'Self-Driving Cars', 'Virtual Assistants', 'Bias', 'Ethics', 'Job Displacement']
# Extracted concepts for chunk 3/42 are ['Artificial Intelligence', 'Machine Learning', 'Bias', 'Job Displacement', 'Supervised Learning', 'Unsupervised Learning']
# Extracted concepts for chunk 4/42 are ['Unsupervised Learning', 'Clustering', 'Dimensionality Reduction', 'Reinforcement Learning', 'Deep Learning', 'Artificial Neural Networks']
# Extracted concepts for chunk 5/42 are ['Deep Learning', 'Convolutional Neural Networks (CNNs)', 'Recurrent Neural Networks (RNNs)', 'Natural Language Processing (NLP)', 'Image Recognition', 'Natural Language Processing (NLP)', 'Speech Recognition', 'Object Detection', 'Facial Recognition', 'Medical Image Analysis']
# Extracted concepts for chunk 6/42 are ['Natural Language Processing (NLP)', 'Artificial Intelligence (AI)', 'Computer Vision', 'Chatbots', 'Machine Translation', 'Text Summarization', 'Sentiment Analysis', 'Computer Vision', 'Object Detection', 'Image Segmentation', 'Facial Recognition', 'Healthcare', 'Medical Diagnosis', 'Personalized Medicine', 'Robotic Surgery']
# Extracted concepts for chunk 7/42 are ['Artificial Intelligence (AI)', 'Machine Learning', 'Medical Diagnosis', 'Personalized Medicine', 'Robotic Surgery', 'Fraud Detection', 'Algorithmic Trading', 'Risk Management', 'Customer Service', 'Autonomous Vehicles', 'Self-Driving Cars', 'Traffic Optimization', 'Logistics Management', 'Inventory Management', 'Supply Chain Optimization', 'Personalized Recommendations']
# Extracted concepts for chunk 8/42 are ['AI-powered systems', 'Customer data analysis', 'Predictive maintenance', 'Personalized learning', 'Content recommendation', 'Cybersecurity', 'Supply chain optimization', 'Manufacturing automation', 'Robotics', 'Virtual reality']
# Extracted concepts for chunk 9/42 are ['AI algorithms', 'Cybersecurity', 'Bias and Fairness', 'Transparency and Explainability', 'Ethical Implications of AI', 'Deep Learning Models', 'User Engagement', 'Network Traffic Analysis', 'Vulnerability Identification', 'Automated Security Tasks']
# Extracted concepts for chunk 10/42 are ['Transparency', 'Explainability', 'Privacy', 'Security', 'Job Displacement', 'Autonomy', 'Accountability', 'Ethics', 'AI Development', 'Data Security']
# Extracted concepts for chunk 11/42 are ['Explainable AI (XAI)', 'Accountability', 'Control', 'Unintended Consequences', 'AI at the Edge', 'Weaponization of AI', 'International Regulations', 'Ethical Frameworks', 'Autonomous Weapons Systems']
# Extracted concepts for chunk 12/42 are ['AI at the Edge', 'Quantum Computing and AI', 'Human-AI Collaboration', 'AI for Social Good', 'Trust and Accountability', 'Decision-making', 'Artificial Intelligence', 'Edge Computing', 'Latency', 'Privacy']
# Extracted concepts for chunk 13/42 are ['Responsible Development', 'Thoughtful Governance', 'International Collaborations', 'Standards']
# Extracted concepts for chunk 14/42 are ['AI', 'Robotics', 'Artificial Intelligence', 'Robot Integration', 'Cognitive Abilities', 'Physical Capabilities', 'Collaborative Robots (cobots)', 'Industrial Robots', 'Service Robots', 'Manufacturing', 'Healthcare']
# Extracted concepts for chunk 15/42 are ['cobots', 'Service Robots', 'Surgical Robots', 'Exploration Robots', 'Robot Learning', 'Imitation Learning', 'Reinforcement Learning']
# Extracted concepts for chunk 16/42 are ['Reinforcement Learning', 'Robot Navigation', 'SLAM (Simultaneous Localization and Mapping)', 'Computer Vision', 'Robotics', 'Autonomous Navigation', 'Trial and Error', 'Reward System', 'Robot Perception', 'AI in Business']
# Extracted concepts for chunk 17/42 are ['Artificial Intelligence (AI)', 'Object Recognition', 'Scene Understanding', 'Obstacle Avoidance', 'Customer Relationship Management (CRM)', 'Supply Chain Management', 'Business Operations', 'Decision-Making', 'Automation', 'Data Analysis']
# Extracted concepts for chunk 18/42 are ['Artificial Intelligence', 'Supply Chain Management', 'Human Resources', 'Marketing and Sales', 'Financial Services', 'Talent Acquisition', 'Employee Onboarding', 'Performance Management', 'Training', 'Recruitment', 'Fraud Detection', 'Risk Management', 'Algorithmic Trading', 'Customer Segmentation']
# Extracted concepts for chunk 19/42 are ['AI-powered systems', 'Algorithmic trading', 'Customer service', 'Automation', 'Job displacement', 'Reskilling', 'Upskilling', 'Human-AI collaboration', 'Future of work']
# Extracted concepts for chunk 20/42 are ['augmentation', 'automation', 'insights', 'fairness', 'transparency', 'accountability', 'worker rights', 'privacy']
# Extracted concepts for chunk 21/42 are ['AI-Generated Art', 'AI in Music Composition', 'AI in Writing and Content Creation', 'AI-Driven Innovation', 'Artificial Intelligence', 'Design Processes', 'Scientific Discovery', 'Innovation', 'Content Generation', 'Creative Expression']
# Extracted concepts for chunk 22/42 are ['AI-powered tools', 'Personalized Learning', 'Adaptive Assessments', 'Virtual Tutors and Learning Assistants', 'AI in Education', 'Machine Learning', 'Data Analysis', 'Research and Development', 'Product Design', 'Problem-Solving']
# Extracted concepts for chunk 23/42 are ['Personalized Learning', 'Automated Grading', 'Educational Data Mining', 'Artificial Intelligence (AI)', 'Medical Diagnosis', 'Medical Treatment', 'Drug Discovery', 'Healthcare', 'Student Support', 'Learning Outcomes']
# Extracted concepts for chunk 24/42 are ['Artificial Intelligence (AI)', 'Medical Imaging', 'Personalized Medicine', 'Drug Discovery and Development', 'Robotic Surgery', 'Healthcare Administration']
# Extracted concepts for chunk 25/42 are ['Artificial Intelligence (AI)', 'Healthcare Administration', 'Cybersecurity', 'Threat Detection', 'Anomaly Detection', 'Fraud Detection', 'Patient Outcomes', 'Efficiency', 'Cost Reduction', 'Patient Experience']
# Extracted concepts for chunk 26/42 are ['Artificial Intelligence (AI)', 'Fraud Detection', 'Vulnerability Management', 'Incident Response', 'Cybersecurity', 'Security Incidents', 'Societal Challenges', 'Climate Change', 'Poverty', 'Healthcare']
# Extracted concepts for chunk 27/42 are ['AI for Social Good', 'Ethical Considerations', 'Public Perception and Trust', 'Addressing Societal Challenges', 'AI-powered solutions', 'Sustainable Development', 'Climate Change', 'Poverty', 'Healthcare Disparities', 'Resource Management']
# Extracted concepts for chunk 28/42 are ['AI', 'Privacy', 'Human Rights', 'Public Perception', 'Trust', 'Global Collaboration', 'Urban Planning', 'Smart Cities', 'Smart Transportation']
# Extracted concepts for chunk 29/42 are ['Smart Transportation', 'AI-powered systems', 'Energy Management', 'Public Safety and Security', 'Environmental Monitoring', 'Autonomous Vehicles', 'Renewable Energy Sources', 'Grid Stability', 'Energy Efficiency', 'Crime Prevention']
# Extracted concepts for chunk 30/42 are ['Environmental Monitoring', 'AI-powered environmental monitoring', 'Deep Learning', 'Explainable AI (XAI)', 'Neuroscience', 'AI Research', 'Air Quality', 'Water Quality', 'Pollution Detection', 'Environmental Protection']
# Extracted concepts for chunk 31/42 are ['AI and Neuroscience', 'AI Safety and Security', 'Human-Centered AI', 'Generative AI', 'Accountability']
# Extracted concepts for chunk 32/42 are ['Generative AI', 'Artistic Expression', 'Collaborative AI', 'AI in Music', 'AI in Visual Arts', 'Creativity', 'Artistic Collaboration', 'AI Tools', 'Artistic Expression', 'Design Assistance']
# Extracted concepts for chunk 33/42 are ['AI in Visual Arts and Design', 'AI in Interactive Media', 'Climate Change Mitigation', 'Precision Agriculture', 'Audio Mixing and Mastering', 'Artificial Intelligence', 'Data Analysis', 'Renewable Energy', 'Carbon Capture and Storage', 'Virtual Reality']
# Extracted concepts for chunk 34/42 are ['AI-powered systems', 'Precision Agriculture', 'Wildlife Conservation', 'Environmental Monitoring', 'Disaster Response', 'Carbon Capture and Storage', 'Climate Impacts', 'Data Analysis', 'Sensors', 'Drones']
# Extracted concepts for chunk 35/42 are ['Artificial Intelligence (AI)', 'Disaster Response', 'Environmental Policy', 'Government Policy', 'Regulation of AI', 'AI Strategy', 'Ethics in AI', 'Innovation', 'Responsible AI Practices', 'Data Analysis']
# Extracted concepts for chunk 36/42 are ['AI', 'Bias', 'Transparency', 'Privacy', 'Safety', 'Ethics', 'Innovation', 'International Cooperation', 'Public Engagement', 'Education']
# Extracted concepts for chunk 37/42 are ['Ethical AI', 'AI Ethics', 'Bias in AI', 'Transparency in AI', 'Explainability in AI', 'Data Protection', 'Respect for Human Rights', 'Privacy', 'Non-Discrimination', 'Beneficence']
# Extracted concepts for chunk 38/42 are ['Explainable AI (XAI)', 'Privacy and Data Protection', 'Accountability and Responsibility', 'Transparency and Explainability', 'Robustness and Reliability']
# Extracted concepts for chunk 39/42 are ['Trust in AI', 'Robustness', 'Reliability', 'User Control', 'Agency', 'Ethical Design', 'Ethical Development', 'Public Engagement', 'Education', 'Decision-Making Processes']
# Extracted concepts for chunk 40/42 are ['Building Trust', 'Ethical Impact Assessments', 'Public Engagement', 'Public Awareness Campaigns', 'Responsible AI Development', 'Continued Research and Innovation', 'Basic Research', 'Applied Research', 'Ethical Guidelines', 'Ethical Standards']
# Extracted concepts for chunk 41/42 are ['Responsible AI', 'Ethics in AI', 'Global Collaboration', 'Education and Workforce Development', 'Human-Centered Approach', 'Artificial Intelligence (AI)', 'Global Challenges', 'Global Opportunities', 'STEM Education', 'Reskilling and Upskilling']
# Extracted concepts for chunk 42/42 are ['STEM education', 'reskilling', 'upskilling', 'lifelong learning', 'Human-Centered Approach', 'AI', 'human values', 'well-being', 'ethics', 'sustainability']
# Creating edges between nodes...
# Node concept is {'Reasoning', 'Data Availability', 'Dartmouth Workshop', 'Generalization', 'Computing Power', 'Problem-Solving', 'Intelligent Systems', 'Symbolic Methods', 'Learning', 'Artificial Intelligence'}
# Node concept is {'Virtual Assistants', 'Machine Learning', 'Expert Systems', 'Deep Learning', 'Ethics', 'Job Displacement', 'Neural Networks', 'Bias', 'Self-Driving Cars', 'Artificial Intelligence'}
# Node concept is {'Machine Learning', 'Supervised Learning', 'Job Displacement', 'Unsupervised Learning', 'Bias', 'Artificial Intelligence'}
# Node concept is {'Reinforcement Learning', 'Deep Learning', 'Unsupervised Learning', 'Dimensionality Reduction', 'Clustering', 'Artificial Neural Networks'}
# Node concept is {'Recurrent Neural Networks (RNNs)', 'Medical Image Analysis', 'Speech Recognition', 'Object Detection', 'Deep Learning', 'Facial Recognition', 'Convolutional Neural Networks (CNNs)', 'Image Recognition', 'Natural Language Processing (NLP)'}
# Node concept is {'Machine Translation', 'Computer Vision', 'Chatbots', 'Object Detection', 'Healthcare', 'Text Summarization', 'Facial Recognition', 'Image Segmentation', 'Sentiment Analysis', 'Medical Diagnosis', 'Robotic Surgery', 'Personalized Medicine', 'Natural Language Processing (NLP)', 'Artificial Intelligence (AI)'}
# Node concept is {'Machine Learning', 'Logistics Management', 'Algorithmic Trading', 'Autonomous Vehicles', 'Fraud Detection', 'Traffic Optimization', 'Customer Service', 'Personalized Recommendations', 'Risk Management', 'Supply Chain Optimization', 'Robotic Surgery', 'Medical Diagnosis', 'Self-Driving Cars', 'Personalized Medicine', 'Inventory Management', 'Artificial Intelligence (AI)'}
# Node concept is {'Robotics', 'Content recommendation', 'Personalized learning', 'Customer data analysis', 'AI-powered systems', 'Manufacturing automation', 'Predictive maintenance', 'Cybersecurity', 'Virtual reality', 'Supply chain optimization'}
# Node concept is {'Network Traffic Analysis', 'User Engagement', 'Vulnerability Identification', 'AI algorithms', 'Deep Learning Models', 'Automated Security Tasks', 'Ethical Implications of AI', 'Transparency and Explainability', 'Bias and Fairness', 'Cybersecurity'}
# Node concept is {'Data Security', 'Explainability', 'Accountability', 'Privacy', 'AI Development', 'Job Displacement', 'Autonomy', 'Ethics', 'Transparency', 'Security'}
# Node concept is {'Accountability', 'Explainable AI (XAI)', 'Ethical Frameworks', 'Weaponization of AI', 'International Regulations', 'Unintended Consequences', 'Control', 'Autonomous Weapons Systems', 'AI at the Edge'}
# Node concept is {'Human-AI Collaboration', 'Edge Computing', 'Privacy', 'Decision-making', 'Artificial Intelligence', 'Latency', 'AI at the Edge', 'Quantum Computing and AI', 'AI for Social Good', 'Trust and Accountability'}
# Node concept is {'Responsible Development', 'Standards', 'International Collaborations', 'Thoughtful Governance'}
# Node concept is {'Manufacturing', 'Robotics', 'AI', 'Healthcare', 'Cognitive Abilities', 'Industrial Robots', 'Physical Capabilities', 'Robot Integration', 'Service Robots', 'Artificial Intelligence', 'Collaborative Robots (cobots)'}
# Node concept is {'cobots', 'Surgical Robots', 'Reinforcement Learning', 'Robot Learning', 'Exploration Robots', 'Service Robots', 'Imitation Learning'}
# Node concept is {'Robot Navigation', 'Robotics', 'Trial and Error', 'Computer Vision', 'Robot Perception', 'Reinforcement Learning', 'AI in Business', 'Reward System', 'SLAM (Simultaneous Localization and Mapping)', 'Autonomous Navigation'}
# Node concept is {'Business Operations', 'Decision-Making', 'Automation', 'Customer Relationship Management (CRM)', 'Data Analysis', 'Scene Understanding', 'Object Recognition', 'Supply Chain Management', 'Obstacle Avoidance', 'Artificial Intelligence (AI)'}
# Node concept is {'Talent Acquisition', 'Employee Onboarding', 'Algorithmic Trading', 'Fraud Detection', 'Customer Segmentation', 'Training', 'Financial Services', 'Recruitment', 'Human Resources', 'Performance Management', 'Supply Chain Management', 'Risk Management', 'Marketing and Sales', 'Artificial Intelligence'}
# Node concept is {'Algorithmic trading', 'Automation', 'AI-powered systems', 'Customer service', 'Upskilling', 'Job displacement', 'Human-AI collaboration', 'Future of work', 'Reskilling'}
# Node concept is {'augmentation', 'transparency', 'automation', 'worker rights', 'insights', 'privacy', 'fairness', 'accountability'}
# Node concept is {'AI in Writing and Content Creation', 'Scientific Discovery', 'AI-Generated Art', 'Design Processes', 'AI-Driven Innovation', 'Content Generation', 'Creative Expression', 'Innovation', 'Artificial Intelligence', 'AI in Music Composition'}
# Node concept is {'AI-powered tools', 'Machine Learning', 'Product Design', 'AI in Education', 'Personalized Learning', 'Data Analysis', 'Virtual Tutors and Learning Assistants', 'Research and Development', 'Problem-Solving', 'Adaptive Assessments'}
# Node concept is {'Educational Data Mining', 'Learning Outcomes', 'Healthcare', 'Medical Treatment', 'Personalized Learning', 'Student Support', 'Drug Discovery', 'Medical Diagnosis', 'Automated Grading', 'Artificial Intelligence (AI)'}
# Node concept is {'Drug Discovery and Development', 'Medical Imaging', 'Healthcare Administration', 'Robotic Surgery', 'Personalized Medicine', 'Artificial Intelligence (AI)'}
# Node concept is {'Cost Reduction', 'Patient Outcomes', 'Patient Experience', 'Fraud Detection', 'Efficiency', 'Threat Detection', 'Healthcare Administration', 'Anomaly Detection', 'Cybersecurity', 'Artificial Intelligence (AI)'}
# Node concept is {'Poverty', 'Security Incidents', 'Incident Response', 'Healthcare', 'Fraud Detection', 'Vulnerability Management', 'Societal Challenges', 'Climate Change', 'Cybersecurity', 'Artificial Intelligence (AI)'}
# Node concept is {'Healthcare Disparities', 'Poverty', 'Resource Management', 'Public Perception and Trust', 'Climate Change', 'Addressing Societal Challenges', 'Sustainable Development', 'AI-powered solutions', 'Ethical Considerations', 'AI for Social Good'}
# Node concept is {'Public Perception', 'Urban Planning', 'AI', 'Privacy', 'Global Collaboration', 'Smart Cities', 'Trust', 'Smart Transportation', 'Human Rights'}
# Node concept is {'Energy Efficiency', 'Autonomous Vehicles', 'AI-powered systems', 'Crime Prevention', 'Public Safety and Security', 'Renewable Energy Sources', 'Grid Stability', 'Environmental Monitoring', 'Smart Transportation', 'Energy Management'}
# Node concept is {'Pollution Detection', 'Water Quality', 'Explainable AI (XAI)', 'Air Quality', 'Deep Learning', 'Neuroscience', 'AI Research', 'Environmental Protection', 'Environmental Monitoring', 'AI-powered environmental monitoring'}
# Node concept is {'Generative AI', 'Accountability', 'AI and Neuroscience', 'Human-Centered AI', 'AI Safety and Security'}
# Node concept is {'Generative AI', 'AI Tools', 'Creativity', 'Artistic Collaboration', 'AI in Visual Arts', 'Collaborative AI', 'AI in Music', 'Design Assistance', 'Artistic Expression'}
# Node concept is {'Climate Change Mitigation', 'Carbon Capture and Storage', 'Audio Mixing and Mastering', 'Virtual Reality', 'AI in Interactive Media', 'AI in Visual Arts and Design', 'Data Analysis', 'Renewable Energy', 'Precision Agriculture', 'Artificial Intelligence'}
# Node concept is {'Wildlife Conservation', 'Carbon Capture and Storage', 'Drones', 'AI-powered systems', 'Data Analysis', 'Climate Impacts', 'Disaster Response', 'Environmental Monitoring', 'Precision Agriculture', 'Sensors'}
# Node concept is {'Environmental Policy', 'Ethics in AI', 'Government Policy', 'Data Analysis', 'Artificial Intelligence (AI)', 'AI Strategy', 'Disaster Response', 'Responsible AI Practices', 'Innovation', 'Regulation of AI'}
# Node concept is {'Safety', 'International Cooperation', 'AI', 'Privacy', 'Ethics', 'Education', 'Transparency', 'Bias', 'Public Engagement', 'Innovation'}
# Node concept is {'Bias in AI', 'AI Ethics', 'Respect for Human Rights', 'Privacy', 'Explainability in AI', 'Data Protection', 'Ethical AI', 'Beneficence', 'Non-Discrimination', 'Transparency in AI'}
# Node concept is {'Explainable AI (XAI)', 'Robustness and Reliability', 'Transparency and Explainability', 'Accountability and Responsibility', 'Privacy and Data Protection'}
# Node concept is {'Decision-Making Processes', 'Agency', 'Trust in AI', 'User Control', 'Robustness', 'Ethical Development', 'Reliability', 'Ethical Design', 'Public Engagement', 'Education'}
# Node concept is {'Ethical Guidelines', 'Ethical Impact Assessments', 'Responsible AI Development', 'Continued Research and Innovation', 'Public Awareness Campaigns', 'Applied Research', 'Public Engagement', 'Basic Research', 'Ethical Standards', 'Building Trust'}
# Node concept is {'Global Challenges', 'Ethics in AI', 'Global Collaboration', 'STEM Education', 'Human-Centered Approach', 'Global Opportunities', 'Reskilling and Upskilling', 'Education and Workforce Development', 'Responsible AI', 'Artificial Intelligence (AI)'}
# Node concept is {'ethics', 'reskilling', 'STEM education', 'AI', 'well-being', 'upskilling', 'Human-Centered Approach', 'human values', 'sustainability', 'lifelong learning'}
# Knowledge graph built with 42 nodes and 61 edges
#
#
# === Evaluating Query 1/1 ===
# Query: How do transformers handle sequential data compared to RNNs?
# Traversing graph for query: How do transformers handle sequential data compared to RNNs?
# Starting traversal from 5 nodes
# Graph traversal found 7 relevant chunks
#
# Response: The provided context does not specifically discuss transformers or how they handle sequential data compared to RNNs. However, I can provide some general information about transformers and their relationship to RNNs.
#
# Transformers are a type of neural network architecture introduced in the 2017 paper "Attention is All You Need" by Vaswani et al. They are particularly effective for handling sequential data, such as text or time series, and have achieved state-of-the-art results in many natural language processing tasks.
#
# Compared to RNNs, transformers use self-attention mechanisms to process sequential data, rather than relying on recurrent connections. This allows transformers to capture long-range dependencies and relationships in the data more effectively.
#
# In the context of the provided text, there is a mention of Recurrent Neural Networks (RNNs) in the section on Natural Language Processing (NLP), but there is no discussion of transformers. However, it is worth noting that transformers are a type of deep neural network, and the section on Deep Learning mentions that deep learning has achieved significant breakthroughs in areas such as image recognition, natural language processing, and speech recognition.
#
# Comparison: The AI response matches the reference answer in terms of correctness, completeness, and relevance to the query.
#
# The response accurately explains the difference between transformers and RNNs in handling sequential data, highlighting the use of self-attention mechanisms in transformers. It also correctly mentions the advantages of transformers, such as capturing long-range dependencies and enabling better parallelization during training.
#
# However, the response is slightly longer and more detailed than the reference answer, which may make it less concise. Additionally, the response does not directly address the query, as it mentions that the provided context does not discuss transformers, whereas the reference answer assumes a general understanding of the topic. Overall, the AI response provides a thorough explanation, but may benefit from a more direct and concise approach.
#
#
# === EVALUATION SUMMARY ===
# Graph nodes: 42
# Graph edges: 61
#
# Query 1: How do transformers handle sequential data compared to RNNs?
# Path length: 7
# Chunks used: 7
